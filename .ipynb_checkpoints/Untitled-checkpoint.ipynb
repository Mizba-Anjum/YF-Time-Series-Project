# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %% [markdown]
# ## Prepare Dataset

# %%
# Get Apple finance data from yfinance
df = yf.download('AAPL', start='2015-01-01', end=None)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Fill missing dates with previous date
df = df.reindex(pd.date_range(df.index[0], df.index[-1], freq='D'), method='ffill')
# Drop adj close and volume columns
df.drop(columns = ["Adj Close", "Volume"], inplace=True)

# %%
df
# Out:
#                   Open        High         Low       Close
# 2015-01-02   27.847500   27.860001   26.837500   27.332500
# 2015-01-03   27.847500   27.860001   26.837500   27.332500
# 2015-01-04   27.847500   27.860001   26.837500   27.332500
# 2015-01-05   27.072500   27.162500   26.352501   26.562500
# 2015-01-06   26.635000   26.857500   26.157499   26.565001
# ...                ...         ...         ...         ...
# 2023-08-28  180.089996  180.589996  178.550003  180.190002
# 2023-08-29  179.699997  184.899994  179.500000  184.119995
# 2023-08-30  184.940002  187.850006  184.740005  187.649994
# 2023-08-31  187.839996  189.119995  187.479996  187.869995
# 2023-09-01  189.490005  189.919998  188.279999  189.460007
#
# [3165 rows x 4 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close
# count  3165.000000  3165.000000  3165.000000  3165.000000
# mean     80.170811    81.050466    79.313380    80.227112
# std      53.516553    54.156222    52.911223    53.571788
# min      22.500000    22.917500    22.367500    22.584999
# 25%      34.695000    34.840000    34.647499    34.747501
# 50%      51.707500    52.185001    51.032501    51.790001
# 75%     134.350006   135.529999   132.809998   134.429993
# max     196.240005   198.229996   195.279999   196.449997

# %%
import matplotlib.pyplot as plt

# %%
# Plot each column over time
for label in df.columns:
    plt.plot(df.index, df[label])
    plt.title(label)
    plt.xlabel("Date")
    plt.ylabel(label)
    plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# scale data
def scale_df(df_to_scale, scaler_to_use):
    return_df_scaled = scaler_to_use.fit_transform(df_to_scale)
    return return_df_scaled

# training data: 70%, validation data: 20%, test data: 10%
def split_data(df_to_split_data):
    train, valid, test = np.split(df_to_split_data, [int(.7*len(df_to_split_data)), int(.9*len(df_to_split_data))])
    return train, valid, test

# split into x (feature) and y (label)
def split_xy(df_to_split_xy, ws):
    x = []
    y = []
    for i in range(len(df_to_split_xy) - ws):
        row = [a for a in df_to_split_xy[i:i+ws]]
        x.append(row)
        y.append(df_to_split_xy[i+ws])
    return np.array(x), np.array(y)

# %%
# use 'close' column
df = df[["Close"]]
# scale df
scaled_df_np = scale_df(df, scaler)
# split df
train, valid, test = split_data(scaled_df_np)
# split into x and y
window_size = 60 # predict by past 60 days
x_train, y_train = split_xy(train, window_size)
x_valid, y_valid = split_xy(valid, window_size)
x_test, y_test = split_xy(test, window_size)

# %% [markdown]
# ## Build Model

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt

# %%
def model_builder(hp):
    model = keras.Sequential()
    # input x
    model.add(keras.layers.InputLayer(input_shape=(x_train.shape[-2], x_train.shape[-1])))
    
    # lstm
    model.add(keras.layers.LSTM(100, return_sequences=True))
    model.add(keras.layers.LSTM(100, return_sequences=False))
    
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 20-30
    hp_units = hp.Int('units', min_value=20, max_value=30, step=2)
    model.add(keras.layers.Dense(units=hp_units, activation='linear'))
    
    # output
    model.add(keras.layers.Dense(x_train.shape[-1], activation='linear'))
    
    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3])
    
    # compile
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.RootMeanSquaredError()])
    
    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective=kt.Objective(keras.metrics.RootMeanSquaredError().name, 'min'),
                     max_epochs=50,
                     factor=5,
                     directory='hypertuning_trials',)
# Out:
# INFO:tensorflow:Reloading Tuner from hypertuning_trials\untitled_project\tuner0.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_root_mean_squared_error', patience=5)
tuner.search(x_train, y_train, validation_data=(x_valid, y_valid), callbacks=[stop_early])
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
best_model = tuner.get_best_models()[0]

# %% [raw]
# model = keras.Sequential()
# model.add(keras.layers.InputLayer(input_shape=(x_train.shape[-2], x_train.shape[-1])))
# model.add(keras.layers.LSTM(100, return_sequences=True))
# model.add(keras.layers.LSTM(100, return_sequences=False))
# model.add(keras.layers.Dense(32, activation='relu'))
# model.add(keras.layers.Dense(x_train.shape[-1], activation='linear'))
#
# model.compile(loss='mse', optimizer='adam', metrics=[keras.metrics.RootMeanSquaredError()])

# %% [raw]
# model.fit(x_train, y_train, epochs=25, batch_size=1, validation_data=(x_valid, y_valid))

# %% [raw]
# best_model = model

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 100)           40800
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 26)                2626
#
#  dense_1 (Dense)             (None, 1)                 27
#
# =================================================================
# Total params: 123853 (483.80 KB)
# Trainable params: 123853 (483.80 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
best_model.get_compile_config()
# Out:
# {'optimizer': {'module': 'keras.optimizers',
#   'class_name': 'Adam',
#   'config': {'name': 'Adam',
#    'weight_decay': None,
#    'clipnorm': None,
#    'global_clipnorm': None,
#    'clipvalue': None,
#    'use_ema': False,
#    'ema_momentum': 0.99,
#    'ema_overwrite_frequency': None,
#    'jit_compile': False,
#    'is_legacy_optimizer': False,
#    'learning_rate': 0.009999999776482582,
#    'beta_1': 0.9,
#    'beta_2': 0.999,
#    'epsilon': 1e-07,
#    'amsgrad': False},
#   'registered_name': None},
#  'loss': {'module': 'keras.losses',
#   'class_name': 'MeanSquaredError',
#   'config': {'reduction': 'auto',
#    'name': 'mean_squared_error',
#    'fn': 'mean_squared_error'},
#   'registered_name': None},
#  'metrics': [{'module': 'keras.metrics',
#    'class_name': 'RootMeanSquaredError',
#    'config': {'name': 'root_mean_squared_error', 'dtype': 'float32'},
#    'registered_name': None}],
#  'loss_weights': None,
#  'weighted_metrics': None,
#  'run_eagerly': None,
#  'steps_per_execution': None,
#  'jit_compile': None}

# %%
eval_result = best_model.evaluate(x_test, y_test)
print("[test loss, test accuracy (rmse)]:", eval_result)
# Out:
# 9/9 [==============================] - 1s 24ms/step - loss: 3.4144e-04 - root_mean_squared_error: 0.0185
# [test loss, test accuracy (rmse)]: [0.00034143938682973385, 0.01847807876765728]

# %% [markdown]
# ## Test

# %%
# y_pred for y_test
y_pred = best_model.predict(x_test)
# unscale
y_pred = scaler.inverse_transform(y_pred)
# Out:
# 9/9 [==============================] - 0s 23ms/step

# %%
test_df = pd.DataFrame(df[-y_test.shape[0]:])
test_df["Predictions"] = y_pred

# %%
rmse = np.sqrt(np.mean(y_pred - y_test)**2)
rmse
# Out:
# 164.1538939914592

# %%
plt.figure(figsize=(16,8))
plt.title('Model Predictions')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)')
plt.plot(df[:-y_test.shape[0]])
plt.plot(test_df[['Close', 'Predictions']])
plt.legend(['Original Data', 'True Values', 'Predictions'], loc='lower right')
plt.show()

# %%
# best_model.save('yfts_best_model.keras')

# %% [markdown]
# ## Predict

# %%
# yfts_best_model = keras.models.load_model('yfts_best_model.keras')

# %%
# df until 2020
chart_df = pd.DataFrame(df.copy().loc[:pd.to_datetime('2023-01-01')])

# %%
# last 30(ws) available datapoints
future_df = pd.DataFrame(chart_df[-window_size:])

# %%
from datetime import timedelta

# %%
#TODO use original scaler with transform NOT fit

# %%
def predict_next_year(future_df, target, window_size):
    # scale dataset
    future_scaler = MinMaxScaler()
    scaled_future_df = scale_df(future_df, future_scaler) # numpy
    target_range = (target - future_df.index[-1]).days # number of days
    
    for i in range(target_range):
        # last 60 entries
        x_data = scaled_future_df[-window_size:].reshape(-1, window_size, 1)
        
        # predict
        future_y_pred = best_model.predict_step(x_data)
        
        # send scaled prediction to scaled dataset
        scaled_future_df = np.vstack([scaled_future_df, future_y_pred[0]])
        print(str(i) + '/' + str(target_range))
    
#     while future_df.index[-1] != target:
#         # get last 30(ws) days
#         future_scaler = MinMaxScaler()
#         x_data = scale_df(pd.DataFrame(future_df[-window_size:]), future_scaler).reshape(-1, window_size, 1)

#         # predict next day
#         future_y_pred = best_model.predict_step(x_data)
#         future_y_pred = future_scaler.inverse_transform(future_y_pred)

#         # add next day to df
#         for i in future_y_pred:
#             new_index = future_df.index[-1] + timedelta(days=1)
#             future_df.loc[new_index] = i
            
#         print(new_index)
    
    # delete first 30(ws) days
#     print(scaled_future_df)

    # unscale scaled dataset and add to df
    scaled_future_df = future_scaler.inverse_transform(scaled_future_df[window_size:])
    for i in scaled_future_df:
            new_index = future_df.index[-1] + timedelta(days=1)
            future_df.loc[new_index] = i
    future_df = pd.DataFrame(future_df[window_size:])
#     scaled_future_df = pd.DataFrame(scaled_future_df)
#     future_df = future_df + scaled_future_df
#     future_df = future_df reindex(future_df.index[0], target, )
#     for j in range(target_range):
#         pass
    # remove first (ws) of df
    return future_df

# %%
target = future_df.index[-1]
target = target.replace(year=target.year + 1)

# %%
target
# Out:
# Timestamp('2024-01-01 00:00:00', freq='D')

# %%
# future_scaler = MinMaxScaler()

# %%
future_df = predict_next_year(future_df, target, window_size)
# Out:
# 0/365
# 1/365
# 2/365
# 3/365
# 4/365
# 5/365
# 6/365
# 7/365
# 8/365
# 9/365
# 10/365
# 11/365
# 12/365
# 13/365
# 14/365
# 15/365
# 16/365
# 17/365
# 18/365
# 19/365
# 20/365
# 21/365
# 22/365
# 23/365
# 24/365
# 25/365
# 26/365
# 27/365
# 28/365
# 29/365
# 30/365
# 31/365
# 32/365
# 33/365
# 34/365
# 35/365
# 36/365
# 37/365
# 38/365
# 39/365
# 40/365
# 41/365
# 42/365
# 43/365
# 44/365
# 45/365
# 46/365
# 47/365
# 48/365
# 49/365
# 50/365
# 51/365
# 52/365
# 53/365
# 54/365
# 55/365
# 56/365
# 57/365
# 58/365
# 59/365
# 60/365
# 61/365
# 62/365
# 63/365
# 64/365
# 65/365
# 66/365
# 67/365
# 68/365
# 69/365
# 70/365
# 71/365
# 72/365
# 73/365
# 74/365
# 75/365
# 76/365
# 77/365
# 78/365
# 79/365
# 80/365
# 81/365
# 82/365
# 83/365
# 84/365
# 85/365
# 86/365
# 87/365
# 88/365
# 89/365
# 90/365
# 91/365
# 92/365
# 93/365
# 94/365
# 95/365
# 96/365
# 97/365
# 98/365
# 99/365
# 100/365
# 101/365
# 102/365
# 103/365
# 104/365
# 105/365
# 106/365
# 107/365
# 108/365
# 109/365
# 110/365
# 111/365
# 112/365
# 113/365
# 114/365
# 115/365
# 116/365
# 117/365
# 118/365
# 119/365
# 120/365
# 121/365
# 122/365
# 123/365
# 124/365
# 125/365
# 126/365
# 127/365
# 128/365
# 129/365
# 130/365
# 131/365
# 132/365
# 133/365
# 134/365
# 135/365
# 136/365
# 137/365
# 138/365
# 139/365
# 140/365
# 141/365
# 142/365
# 143/365
# 144/365
# 145/365
# 146/365
# 147/365
# 148/365
# 149/365
# 150/365
# 151/365
# 152/365
# 153/365
# 154/365
# 155/365
# 156/365
# 157/365
# 158/365
# 159/365
# 160/365
# 161/365
# 162/365
# 163/365
# 164/365
# 165/365
# 166/365
# 167/365
# 168/365
# 169/365
# 170/365
# 171/365
# 172/365
# 173/365
# 174/365
# 175/365
# 176/365
# 177/365
# 178/365
# 179/365
# 180/365
# 181/365
# 182/365
# 183/365
# 184/365
# 185/365
# 186/365
# 187/365
# 188/365
# 189/365
# 190/365
# 191/365
# 192/365
# 193/365
# 194/365
# 195/365
# 196/365
# 197/365
# 198/365
# 199/365
# 200/365
# 201/365
# 202/365
# 203/365
# 204/365
# 205/365
# 206/365
# 207/365
# 208/365
# 209/365
# 210/365
# 211/365
# 212/365
# 213/365
# 214/365
# 215/365
# 216/365
# 217/365
# 218/365
# 219/365
# 220/365
# 221/365
# 222/365
# 223/365
# 224/365
# 225/365
# 226/365
# 227/365
# 228/365
# 229/365
# 230/365
# 231/365
# 232/365
# 233/365
# 234/365
# 235/365
# 236/365
# 237/365
# 238/365
# 239/365
# 240/365
# 241/365
# 242/365
# 243/365
# 244/365
# 245/365
# 246/365
# 247/365
# 248/365
# 249/365
# 250/365
# 251/365
# 252/365
# 253/365
# 254/365
# 255/365
# 256/365
# 257/365
# 258/365
# 259/365
# 260/365
# 261/365
# 262/365
# 263/365
# 264/365
# 265/365
# 266/365
# 267/365
# 268/365
# 269/365
# 270/365
# 271/365
# 272/365
# 273/365
# 274/365
# 275/365
# 276/365
# 277/365
# 278/365
# 279/365
# 280/365
# 281/365
# 282/365
# 283/365
# 284/365
# 285/365
# 286/365
# 287/365
# 288/365
# 289/365
# 290/365
# 291/365
# 292/365
# 293/365
# 294/365
# 295/365
# 296/365
# 297/365
# 298/365
# 299/365
# 300/365
# 301/365
# 302/365
# 303/365
# 304/365
# 305/365
# 306/365
# 307/365
# 308/365
# 309/365
# 310/365
# 311/365
# 312/365
# 313/365
# 314/365
# 315/365
# 316/365
# 317/365
# 318/365
# 319/365
# 320/365
# 321/365
# 322/365
# 323/365
# 324/365
# 325/365
# 326/365
# 327/365
# 328/365
# 329/365
# 330/365
# 331/365
# 332/365
# 333/365
# 334/365
# 335/365
# 336/365
# 337/365
# 338/365
# 339/365
# 340/365
# 341/365
# 342/365
# 343/365
# 344/365
# 345/365
# 346/365
# 347/365
# 348/365
# 349/365
# 350/365
# 351/365
# 352/365
# 353/365
# 354/365
# 355/365
# 356/365
# 357/365
# 358/365
# 359/365
# 360/365
# 361/365
# 362/365
# 363/365
# 364/365

# %%
future_df
# Out:
#                  Close
# 2023-01-02  129.908435
# 2023-01-03  130.605073
# 2023-01-04  131.066009
# 2023-01-05  131.085402
# 2023-01-06  130.852874
# ...                ...
# 2023-12-28  147.231994
# 2023-12-29  147.232086
# 2023-12-30  147.232171
# 2023-12-31  147.232257
# 2024-01-01  147.232340
#
# [365 rows x 1 columns]

# %%
plt.figure(figsize=(16,8))
plt.title('Model Predictions')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)')
plt.plot(df)
plt.plot(chart_df)
plt.plot(future_df)
plt.legend(['Full Data', 'Original Data', 'Predictions'], loc='lower right')
plt.show()
